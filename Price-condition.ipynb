# %%
import pandas as pd

data = [[10.3,10.5,10.1,11.2],[1,2,3,4]]
my_index = ['a','b']
my_columns = ['A','B','C','D']
df = pd.DataFrame(data,index = my_index, columns = ['b','c',12,'e'])
df
# Out:
#       b     c    12     e
# a  10.3  10.5  10.1  11.2
# b   1.0   2.0   3.0   4.0

# %%
import yfinance as yf
import time 
from datetime import datetime
data = yf.download('TSLA', start='2002-08-01', end='2022-08-10')
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2022-08-03  305.000000  309.549988  301.149994  307.396667  307.396667
# 2022-08-04  311.000000  313.606659  305.000000  308.633331  308.633331
# 2022-08-05  302.670013  304.606659  285.543335  288.170013  288.170013
# 2022-08-08  295.000000  305.200012  289.086670  290.423340  290.423340
# 2022-08-09  290.293335  292.396667  279.353333  283.333344  283.333344
#
#                Volume
# Date
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.ylabel('some number')
plt.plot([1,2,3,4],[1,2,3,4])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([130,147,138,185,174,166,153,162,168])
y = np.array([96,73,88,92,81,70,69,85,84])
plt.title('scatter plot')
plt.ylim(60,100)
plt.xlim(100,200)
plt.scatter(x,y)
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %%
x = np.random.randn(10000)

plt.title('Histogram')
plt.xlabel('Random data')
plt.ylabel('Freq')
plt.hist(x,50)
plt.show()

# %%
x =['kaprao','kaikem','numtom','guncha']
boy =[70,65,30,58]
girl=[10,10,10,20]
plt.bar(x,girl, color='cyan')
plt.bar(x,boy, color='k' ,bottom=girl)
plt.title('Bar Graph')
plt.xlabel('type')
plt.ylabel('Range')
plt.show()

# %%
x = np.random.randn(10000)

plt.title('Histogram')
plt.xlabel('Random data')
plt.ylabel('Freq')
plt.hist(x,50)
plt.show()

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.show()

# %%
a = [1, 2, 3, 4, 5]
b = [0, 0.6, 0.2, 15, 10, 8, 16, 21]
c = [4, 2, 6, 8, 3, 20, 13, 15]

fig = plt.figure(figsize =(10, 10))
  
sub1 = plt.subplot(2, 2, 1)
sub2 = plt.subplot(2, 2, 2)
sub3 = plt.subplot(2, 2, 3)
sub4 = plt.subplot(2, 2, 4)
  
sub1.plot(a, 'sb')
sub1.set_xticks(list(range(0, 10, 1)))
sub1.set_title('1st')
  
sub2.plot(b, 'or')
sub2.set_xticks(list(range(0, 10, 2)))
sub2.set_title('2nd')
  
sub3.plot(list(range(0, 22, 3)), 'vg')
sub3.set_xticks(list(range(0, 10, 1)))
sub3.set_title('3rd')
  
sub4.plot(c, 'Dm')
sub4.set_yticks(list(range(0, 24, 2)))
sub4.set_title('4th')
  
plt.show()

# %%
data = yf.download(tickers = 'SPY')
data.plot()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <AxesSubplot:xlabel='Date'>

# %%
from pandas_datareader import data as pdr
import pandas as pd

import yfinance as yf
yf.pdr_override()

# %%
EURUSD = pdr.get_data_yahoo("EURUSD=X" , start='2019-01-01', end='2021-07-07')

EURUSD
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2018-12-31  1.143890  1.146592  1.142231  1.143995   1.143995       0
# 2019-01-01  1.149425  1.155001  1.146500  1.149306   1.149306       0
# 2019-01-02  1.146132  1.149700  1.134572  1.146171   1.146171       0
# 2019-01-03  1.131734  1.140914  1.131734  1.131811   1.131811       0
# 2019-01-04  1.139095  1.141774  1.134816  1.139108   1.139108       0
# ...              ...       ...       ...       ...        ...     ...
# 2021-06-30  1.189994  1.191043  1.184582  1.190193   1.190193       0
# 2021-07-01  1.185536  1.188399  1.183810  1.185677   1.185677       0
# 2021-07-02  1.184708  1.186099  1.181935  1.184624   1.184624       0
# 2021-07-05  1.185593  1.188200  1.185201  1.185621   1.185621       0
# 2021-07-06  1.186150  1.189626  1.181500  1.186380   1.186380       0
#
# [656 rows x 6 columns]

# %%
data.Close.pct_change(30).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import pandas as pd
import yfinance as yf

# %%
data_csv=pd.read_csv(r'C:\Users\kongp\Downloads\tesla.csv')

# %%
data_csv
# Out:
#            Date         Open         High          Low        Close  \
# 0    2021-01-04   719.460022   744.489990   717.190002   729.770020
# 1    2021-01-05   723.659973   740.840027   719.200012   735.109985
# 2    2021-01-06   758.489990   774.000000   749.099976   755.979980
# 3    2021-01-07   777.630005   816.989990   775.200012   816.039978
# 4    2021-01-08   856.000000   884.489990   838.390015   880.020020
# ..          ...          ...          ...          ...          ...
# 247  2021-12-27  1073.670044  1117.000000  1070.719971  1093.939941
# 248  2021-12-28  1109.489990  1119.000000  1078.420044  1088.469971
# 249  2021-12-29  1098.640015  1104.000000  1064.140015  1086.189941
# 250  2021-12-30  1061.329956  1095.550049  1053.150024  1070.339966
# 251  2021-12-31  1073.439941  1082.000000  1054.589966  1056.780029
#
#        Adj Close    Volume
# 0     729.770020  48638200
# 1     735.109985  32245200
# 2     755.979980  44700000
# 3     816.039978  51498900
# ...

# %%
data = yf.download('TSLA')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2022-08-29  282.829987  287.739990  280.700012  284.820007  284.820007
# 2022-08-30  287.869995  288.480011  272.649994  277.700012  277.700012
# 2022-08-31  280.619995  281.250000  271.809998  275.609985  275.609985
# 2022-09-01  272.579987  277.579987  266.149994  277.160004  277.160004
# 2022-09-02  281.070007  282.350006  269.079987  270.209991  270.209991
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %%
data = pd.read_csv('tesla.csv')

# %%
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1     2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2     2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3     2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4     2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...          ...         ...         ...         ...         ...         ...
# 3063  2022-08-29  282.829987  287.739990  280.700012  284.820007  284.820007
# 3064  2022-08-30  287.869995  288.480011  272.649994  277.700012  277.700012
# 3065  2022-08-31  280.619995  281.250000  271.809998  275.609985  275.609985
# 3066  2022-09-01  272.579987  277.579987  266.149994  277.160004  277.160004
# 3067  2022-09-02  281.070007  282.350006  269.079987  270.209991  270.209991
#
#          Volume
# 0     281494500
# ...

# %%
import yfinance as yf
import pandas as pd

# %%
data = yf.download('BTC-USD',start= '2021-01-01', end= '2021-05-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-12-31  28841.574219  29244.876953  28201.992188  29001.720703
# 2021-01-01  28994.009766  29600.626953  28803.585938  29374.152344
# 2021-01-02  29376.455078  33155.117188  29091.181641  32127.267578
# 2021-01-03  32129.408203  34608.558594  32052.316406  32782.023438
# 2021-01-04  32810.949219  33440.218750  28722.755859  31971.914062
# ...                  ...           ...           ...           ...
# 2021-04-26  49077.792969  54288.003906  48852.796875  54021.753906
# 2021-04-27  54030.304688  55416.964844  53319.187500  55033.117188
# 2021-04-28  55036.636719  56227.207031  53887.917969  54824.703125
# 2021-04-29  54858.089844  55115.843750  52418.027344  53555.109375
# 2021-04-30  53568.664062  57900.718750  53129.601562  57750.175781
#
#                Adj Close       Volume
# Date
# 2020-12-31  29001.720703  46754964848
# 2021-01-01  29374.152344  40730301359
# ...

# %%
df = data.copy()

# %%
df['return'] = df['Close'].pct_change()

# %%
df
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-12-31  28841.574219  29244.876953  28201.992188  29001.720703
# 2021-01-01  28994.009766  29600.626953  28803.585938  29374.152344
# 2021-01-02  29376.455078  33155.117188  29091.181641  32127.267578
# 2021-01-03  32129.408203  34608.558594  32052.316406  32782.023438
# 2021-01-04  32810.949219  33440.218750  28722.755859  31971.914062
# ...                  ...           ...           ...           ...
# 2021-04-26  49077.792969  54288.003906  48852.796875  54021.753906
# 2021-04-27  54030.304688  55416.964844  53319.187500  55033.117188
# 2021-04-28  55036.636719  56227.207031  53887.917969  54824.703125
# 2021-04-29  54858.089844  55115.843750  52418.027344  53555.109375
# 2021-04-30  53568.664062  57900.718750  53129.601562  57750.175781
#
#                Adj Close       Volume    return
# Date
# 2020-12-31  29001.720703  46754964848       NaN
# 2021-01-01  29374.152344  40730301359  0.012842
# ...

# %%
df[df.Close > 60000]
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-03-13  57343.371094  61683.863281  56217.972656  61243.085938
# 2021-04-11  59846.230469  60790.554688  59289.796875  60204.964844
# 2021-04-13  59890.019531  63742.285156  59869.957031  63503.457031
# 2021-04-14  63523.753906  64863.097656  61554.796875  63109.695312
# 2021-04-15  63075.195312  63821.671875  62208.964844  63314.011719
# 2021-04-16  63258.503906  63594.722656  60222.531250  61572.789062
# 2021-04-17  61529.921875  62572.175781  60361.351562  60683.820312
#
#                Adj Close       Volume    return
# Date
# 2021-03-13  61243.085938  60669829814  0.068217
# 2021-04-11  60204.964844  46280252580  0.006886
# 2021-04-13  63503.457031  69983454362  0.060274
# 2021-04-14  63109.695312  77451779687 -0.006201
# 2021-04-15  63314.011719  60954381579  0.003237
# 2021-04-16  61572.789062  84293007468 -0.027501
# 2021-04-17  60683.820312  66138759198 -0.014438

# %%
df[df['return'] > 0]
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-01-01  28994.009766  29600.626953  28803.585938  29374.152344
# 2021-01-02  29376.455078  33155.117188  29091.181641  32127.267578
# 2021-01-03  32129.408203  34608.558594  32052.316406  32782.023438
# 2021-01-05  31977.041016  34437.589844  30221.187500  33992.429688
# 2021-01-06  34013.613281  36879.699219  33514.035156  36824.363281
# ...                  ...           ...           ...           ...
# 2021-04-15  63075.195312  63821.671875  62208.964844  63314.011719
# 2021-04-20  55681.792969  57062.148438  53448.046875  56473.031250
# 2021-04-26  49077.792969  54288.003906  48852.796875  54021.753906
# 2021-04-27  54030.304688  55416.964844  53319.187500  55033.117188
# 2021-04-30  53568.664062  57900.718750  53129.601562  57750.175781
#
#                Adj Close       Volume    return
# Date
# 2021-01-01  29374.152344  40730301359  0.012842
# 2021-01-02  32127.267578  67865420765  0.093726
# ...

# %%
def con(df):
    if(df > 0):
        print('Gain')
    elif(df < 0):
        print('loss')
for i in range(len(df.Close)):
    con(df.iloc[i,-1])
# Out:
# Gain
# Gain
# Gain
# loss
# Gain
# Gain
# Gain
# Gain
# loss
# loss
# loss
# loss
# Gain
# Gain
# loss
# loss
# loss
# Gain
# loss
# loss
# loss
# Gain
# loss
# Gain
# Gain
# Gain
# loss
# Gain
# Gain
# loss
# loss
# Gain
# Gain
# Gain
# loss
# Gain
# Gain
# loss
# Gain
# Gain
# loss
# Gain
# loss
# loss
# Gain
# loss
# Gain
# Gain
# loss
# Gain
# Gain
# Gain
# loss
# loss
# Gain
# loss
# loss
# loss
# loss
# Gain
# loss
# Gain
# loss
# Gain
# loss
# Gain
# Gain
# Gain
# Gain
# Gain
# loss
# Gain
# loss
# loss
# Gain
# Gain
# loss
# Gain
# loss
# loss
# loss
# Gain
# loss
# loss
# Gain
# Gain
# loss
# Gain
# Gain
# Gain
# Gain
# Gain
# loss
# Gain
# Gain
# loss
# loss
# Gain
# loss
# Gain
# Gain
# loss
# Gain
# loss
# Gain
# loss
# loss
# loss
# loss
# Gain
# loss
# loss
# loss
# loss
# loss
# Gain
# Gain
# loss
# loss
# Gain

# %%
# Out:
#   Input In [1]
#     self.name = name
#     ^
# IndentationError: expected an indented block after function definition on line 2
